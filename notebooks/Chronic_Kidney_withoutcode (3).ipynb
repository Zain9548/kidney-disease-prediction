# %% [markdown]
# ![](https://www.miskawaanhealth.com/wp-content/uploads/2021/05/chronic-kidney-disease-stages.jpg)

# %%
#import necessary libraries like numpy, pandas, pyplot and seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading dataset
chronic_df = pd.read_csv('kidney_disease.csv')
chronic_df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %% [markdown]
# ## **`Dataset Description`**
# - age		-	age
# - bp		-	blood pressure
# - sg		-	specific gravity
# - al		-   	albumin
# - su		-	sugar
# - rbc		-	red blood cells
# - pc		-	pus cell
# - pcc		-	pus cell clumps
# - ba		-	bacteria
# - 	bgr		-	blood glucose random
# -			bu		-	blood urea
# -			sc		-	serum creatinine
# -			sod		-	sodium
# -			pot		-	potassium
# -			hemo		-	hemoglobin
# -			pcv		-	packed cell volume
# -			wc		-	white blood cell count
# -			rc		-	red blood cell count
# -			htn		-	hypertension
# -			dm		-	diabetes mellitus
# -			cad		-	coronary artery disease
# -			appet		-	appetite
# -			pe		-	pedal edema
# -			ane		-	anemia
# -			class		-	class
# - ##################################################
# %
# - Number of Attributes: 24 + class = 25 ( 11  numeric ,14  nominal)
# %
# <h3>Attribute Information :</h3>
# - 1.Age(numerical)
#   	  	age in years
# - 	2.Blood Pressure(numerical)
# 	       	bp in mm/Hg
# -	3.Specific Gravity(nominal)
# 	  	sg - (1.005,1.010,1.015,1.020,1.025)
# - 	4.Albumin(nominal)
# 		  al - (0,1,2,3,4,5)
# -	5.Sugar(nominal)
# 		  su - (0,1,2,3,4,5)
# - 	6.Red Blood Cells(nominal)
# 		  rbc - (normal,abnormal)
# - 	7.Pus Cell (nominal)
# 		  pc - (normal,abnormal)
# - 	8.Pus Cell clumps(nominal)
# 		  pcc - (present,notpresent)
# - 	9.Bacteria(nominal)
# 		  ba  - (present,notpresent)
# - 	10.Blood Glucose Random(numerical)
# 		  bgr in mgs/dl
# - 	11.Blood Urea(numerical)
# 		  bu in mgs/dl
# - 	12.Serum Creatinine(numerical)
# 		  sc in mgs/dl
# - 	13.Sodium(numerical)
# 		  sod in mEq/L
# - 	14.Potassium(numerical)
# 		  pot in mEq/L
# - 	15.Hemoglobin(numerical)
# 		  hemo in gms
# - 	16.Packed  Cell Volume(numerical)
# - 	17.White Blood Cell Count(numerical)
# 		  wc in cells/cumm
# - 	18.Red Blood Cell Count(numerical)
# 		  rc in millions/cmm
# - 	19.Hypertension(nominal)
# 		  htn - (yes,no)
# - 	20.Diabetes Mellitus(nominal)
# 		  dm - (yes,no)
# - 	21.Coronary Artery Disease(nominal)
# 		  cad - (yes,no)
# - 	22.Appetite(nominal)
# 	    appet - (good,poor)
# - 	23.Pedal Edema(nominal)
# 		  pe - (yes,no)
# - 	24.Anemia(nominal)
# 		  ane - (yes,no)
# - 	25.Class (nominal)
# 		  class - (ckd,notckd)

# %%
# checking info of columns and null values
chronic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
#  17  wc              295 non-null    object
#  18  rc              270 non-null    object
#  19  htn             398 non-null    object
#  20  dm              398 non-null    object
#  21  cad             398 non-null    object
#  22  appet           399 non-null    object
#  23  pe              399 non-null    object
#  24  ane             399 non-null    object
#  25  classification  400 non-null    object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 81.4+ KB

# %%
chronic_df.isna().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %% [markdown]
# ## **`Data Cleaning`**

# %%
# drop id column
chronic_df = chronic_df.drop(columns=['id','appet','pe','cad','sod','pot','wc','ba','pcc','ane'], errors='ignore')
#chronic_df = chronic_df.drop('id',axis=1)

# %%
chronic_df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'bgr', 'bu', 'sc', 'hemo',
#        'pcv', 'rc', 'htn', 'dm', 'classification'],
#       dtype='object')

# %%
# rename column names to make it more user-friendly

chronic_df.columns = ['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
              'blood_glucose_random', 'blood_urea', 'serum_creatinine',
              'haemoglobin', 'packed_cell_volume','red_blood_cell_count',
              'hypertension', 'diabetes_mellitus','class']

# %%
chronic_df.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0             NaN
# 1   7.0            50.0             1.020      4.0    0.0             NaN
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
# 4  51.0            80.0             1.010      2.0    0.0          normal
#
#    pus_cell  blood_glucose_random  blood_urea  serum_creatinine  haemoglobin  \
# 0    normal                 121.0        36.0               1.2         15.4
# 1    normal                   NaN        18.0               0.8         11.3
# 2    normal                 423.0        53.0               1.8          9.6
# 3  abnormal                 117.0        56.0               3.8         11.2
# 4    normal                 106.0        26.0               1.4         11.6
#
#   packed_cell_volume red_blood_cell_count hypertension diabetes_mellitus class
# 0                 44                  5.2          yes               yes   ckd
# 1                 38                  NaN           no                no   ckd
# 2                 31                  NaN           no               yes   ckd
# 3                 32                  3.9          yes                no   ckd
# 4                 35                  4.6           no                no   ckd

# %%
chronic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   391 non-null    float64
#  1   blood_pressure        388 non-null    float64
#  2   specific_gravity      353 non-null    float64
#  3   albumin               354 non-null    float64
#  4   sugar                 351 non-null    float64
#  5   red_blood_cells       248 non-null    object
#  6   pus_cell              335 non-null    object
#  7   blood_glucose_random  356 non-null    float64
#  8   blood_urea            381 non-null    float64
#  9   serum_creatinine      383 non-null    float64
#  10  haemoglobin           348 non-null    float64
#  11  packed_cell_volume    330 non-null    object
#  12  red_blood_cell_count  270 non-null    object
#  13  hypertension          398 non-null    object
#  14  diabetes_mellitus     398 non-null    object
#  15  class                 400 non-null    object
# dtypes: float64(9), object(7)
# memory usage: 50.1+ KB

# %% [markdown]
# ### According to the data description
# - Cols(pcv, wc and rc) needs to convert back in numerical since it is object right now
# - Cols(sg, al and su) should be nominal , convert from float to object

# %%
# Categorical cols like specific_gravity, albumin and sugar which is float type right now
# converting back to nominal data type categorical
chronic_df[['specific_gravity','albumin','sugar']]=chronic_df[['specific_gravity','albumin','sugar']].astype('object')

# %%
# converting necessary columns like packed_cell_volume, white-blood_cell_count and red_blood_cell_count
# currently it is in object type and converting back to numerical type
chronic_df['packed_cell_volume']=pd.to_numeric(chronic_df['packed_cell_volume'],errors='coerce')
#chronic_df['white_blood_cell_count']=pd.to_numeric(chronic_df['white_blood_cell_count'],errors='coerce')
chronic_df['red_blood_cell_count']=pd.to_numeric(chronic_df['red_blood_cell_count'],errors='coerce')

# %%
# Extracting categorical and numerical columns
cat_cols =[col for col in chronic_df.columns if chronic_df[col].dtype=='object']
num_cols =[col for col in chronic_df.columns if chronic_df[col].dtype!='object']

# %%
print("categorical:",cat_cols)
print("numerical:",num_cols)
# Out:
# categorical: ['specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell', 'hypertension', 'diabetes_mellitus', 'class']
# numerical: ['age', 'blood_pressure', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'haemoglobin', 'packed_cell_volume', 'red_blood_cell_count']

# %%
cat_cols
# Out:
# ['specific_gravity',
#  'albumin',
#  'sugar',
#  'red_blood_cells',
#  'pus_cell',
#  'hypertension',
#  'diabetes_mellitus',
#  'class']

# %%
num_cols
# Out:
# ['age',
#  'blood_pressure',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'haemoglobin',
#  'packed_cell_volume',
#  'red_blood_cell_count']

# %%
# by looping & looking at unique values in categorical columns
for col in cat_cols:
    print(f"{col} has {chronic_df[col].unique()} values\n")
# Out:
# specific_gravity has [1.02 1.01 1.005 1.015 nan 1.025] values
#
# albumin has [1.0 4.0 2.0 3.0 0.0 nan 5.0] values
#
# sugar has [0.0 3.0 4.0 1.0 nan 2.0 5.0] values
#
# red_blood_cells has [nan 'normal' 'abnormal'] values
#
# pus_cell has ['normal' 'abnormal' nan] values
#
# hypertension has ['yes' 'no' nan] values
#
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# class has ['ckd' 'ckd\t' 'notckd'] values

# %%
# replace incorrect values like '\tno', '\tyes', ' yes', '\tno', 'ckd\t', 'notckd'  in categorical cols

chronic_df['diabetes_mellitus'].replace({'yes':'yes','\tno':'no','tyes':'yes'},inplace=True)
#chronic_df['coronary_artery_disease'].replace({'\tno':'no'},inplace=True)
chronic_df['class'].replace({'ckd\t':'ckd'},inplace=True)
# Out:
# C:\Users\ajeem\AppData\Local\Temp\ipykernel_18444\2943578415.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   chronic_df['diabetes_mellitus'].replace({'yes':'yes','\tno':'no','tyes':'yes'},inplace=True)
# C:\Users\ajeem\AppData\Local\Temp\ipykernel_18444\2943578415.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   chronic_df['class'].replace({'ckd\t':'ckd'},inplace=True)

# %%
# by looping & looking at unique values in categorical columns
for col in cat_cols:
    print(f"{col} has {chronic_df[col].unique()} values\n")
# Out:
# specific_gravity has [1.02 1.01 1.005 1.015 nan 1.025] values
#
# albumin has [1.0 4.0 2.0 3.0 0.0 nan 5.0] values
#
# sugar has [0.0 3.0 4.0 1.0 nan 2.0 5.0] values
#
# red_blood_cells has [nan 'normal' 'abnormal'] values
#
# pus_cell has ['normal' 'abnormal' nan] values
#
# hypertension has ['yes' 'no' nan] values
#
# diabetes_mellitus has ['yes' 'no' ' yes' '\tyes' nan] values
#
# class has ['ckd' 'notckd'] values

# %%
# Converting target col class into 0(chronic kidney) and 1(not a chronic kidney)
chronic_df['class']=chronic_df['class'].map({'ckd':0,'notckd':1})



# coverting target col into numeric to check correlation
chronic_df['class']=pd.to_numeric(chronic_df['class'],errors='coerce')

# %%
chronic_df.head()
# Out:
#     age  blood_pressure specific_gravity albumin sugar red_blood_cells  \
# 0  48.0            80.0             1.02     1.0   0.0             NaN
# 1   7.0            50.0             1.02     4.0   0.0             NaN
# 2  62.0            80.0             1.01     2.0   3.0          normal
# 3  48.0            70.0            1.005     4.0   0.0          normal
# 4  51.0            80.0             1.01     2.0   0.0          normal
#
#    pus_cell  blood_glucose_random  blood_urea  serum_creatinine  haemoglobin  \
# 0    normal                 121.0        36.0               1.2         15.4
# 1    normal                   NaN        18.0               0.8         11.3
# 2    normal                 423.0        53.0               1.8          9.6
# 3  abnormal                 117.0        56.0               3.8         11.2
# 4    normal                 106.0        26.0               1.4         11.6
#
#    packed_cell_volume  red_blood_cell_count hypertension diabetes_mellitus  \
# 0                44.0                   5.2          yes               yes
# 1                38.0                   NaN           no                no
# 2                31.0                   NaN           no               yes
# 3                32.0                   3.9          yes                no
# 4                35.0                   4.6           no                no
#
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
# let's see the cols in numerical col list
num_cols
# Out:
# ['age',
#  'blood_pressure',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'haemoglobin',
#  'packed_cell_volume',
#  'red_blood_cell_count']

# %% [markdown]
# ## **`EDA`**

# %%
# checking numerical features distribution


plt.figure(figsize=(20,12))

# looping over num cols and checking its distribution
for col in num_cols:
    sns.displot(chronic_df[col],kind='kde')
    plt.show()

# %%
# let's see the cols in cat col list
cat_cols
# Out:
# ['specific_gravity',
#  'albumin',
#  'sugar',
#  'red_blood_cells',
#  'pus_cell',
#  'hypertension',
#  'diabetes_mellitus',
#  'class']

# %%
# checking cat features distribution

# create the figure and axes


fig, axes = plt.subplots(3, 5, figsize=(16,8))


axes = axes.ravel()  # flattening the array makes indexing easier

# loop over cat cols and plot countplot
for col,ax in zip(cat_cols,axes):
    sns.countplot(data=chronic_df,x=col,ax=ax)
    plt.xlabel(col)
    #plt.show()
    fig.tight_layout()
# Out:
# C:\Users\ajeem\AppData\Local\Temp\ipykernel_18444\624166555.py:16: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\ajeem\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:82: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\ajeem\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# correlated heatmap of data
numeric_df = chronic_df.select_dtypes(include=['number'])

plt.figure(figsize = (15, 8))
sns.heatmap(numeric_df.corr(),annot=True,linewidths=2,linecolor='lightgrey')
plt.show()

# %%
# let's check count of null values in whole df
chronic_df.isna().sum().sort_values(ascending=False)
# Out:
# red_blood_cells         152
# red_blood_cell_count    131
# packed_cell_volume       71
# pus_cell                 65
# haemoglobin              52
# sugar                    49
# specific_gravity         47
# albumin                  46
# blood_glucose_random     44
# blood_urea               19
# serum_creatinine         17
# blood_pressure           12
# age                       9
# hypertension              2
# diabetes_mellitus         2
# class                     0
# dtype: int64

# %%
# let's check count of null values in num_cols
chronic_df[cat_cols].isna().sum().sort_values(ascending=False)
# Out:
# red_blood_cells      152
# pus_cell              65
# sugar                 49
# specific_gravity      47
# albumin               46
# hypertension           2
# diabetes_mellitus      2
# class                  0
# dtype: int64

# %%
# let's check count of null values in cat cols
chronic_df[num_cols].isna().sum().sort_values(ascending=False)
# Out:
# red_blood_cell_count    131
# packed_cell_volume       71
# haemoglobin              52
# blood_glucose_random     44
# blood_urea               19
# serum_creatinine         17
# blood_pressure           12
# age                       9
# dtype: int64

# %% [markdown]
# ## **`Missing Value Treatment`**

# %%
# filling null values, we will use two methods, random sampling for higher null values and 
# mean/mode sampling for lower null values

# creating func for imputing random values
def random_value_imputation(feature): 
    
    random_sample = chronic_df[feature].dropna().sample(chronic_df[feature].isna().sum())
    random_sample.index = chronic_df[chronic_df[feature].isnull()].index
    chronic_df.loc[chronic_df[feature].isnull(), feature] = random_sample
    
# creating func for imputing most common value(modal value)
def impute_mode(feature):
    mode = chronic_df[feature].mode()[0]
    chronic_df[feature] = chronic_df[feature].fillna(mode)

# %%
# filling num_cols null values using random sampling method
for col in num_cols:
    random_value_imputation(col)

# %%
# let's check count of null values in num_cols again
chronic_df[num_cols].isna().sum().sort_values(ascending=False)
# Out:
# age                     0
# blood_pressure          0
# blood_glucose_random    0
# blood_urea              0
# serum_creatinine        0
# haemoglobin             0
# packed_cell_volume      0
# red_blood_cell_count    0
# dtype: int64

# %%
# filling "red_blood_cells" and "pus_cell" using random sampling method and rest of cat_cols using mode imputation
random_value_imputation("red_blood_cells")
random_value_imputation('pus_cell')

# %%
# let's check count of null values in cat_cols again
chronic_df[cat_cols].isna().sum().sort_values(ascending=False)
# Out:
# sugar                49
# specific_gravity     47
# albumin              46
# hypertension          2
# diabetes_mellitus     2
# red_blood_cells       0
# pus_cell              0
# class                 0
# dtype: int64

# %%
#filling cat null values with mode treamtment
for col in cat_cols:
    impute_mode(col)
# Out:
# C:\Users\ajeem\AppData\Local\Temp\ipykernel_18444\426230361.py:14: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   chronic_df[feature] = chronic_df[feature].fillna(mode)

# %%
# let's check count of null values in cat_cols again
chronic_df[cat_cols].isna().sum().sort_values(ascending=False)
# Out:
# specific_gravity     0
# albumin              0
# sugar                0
# red_blood_cells      0
# pus_cell             0
# hypertension         0
# diabetes_mellitus    0
# class                0
# dtype: int64

# %%
#checking the head of df 
chronic_df.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0        abnormal
# 1   7.0            50.0             1.020      4.0    0.0          normal
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
# 4  51.0            80.0             1.010      2.0    0.0          normal
#
#    pus_cell  blood_glucose_random  blood_urea  serum_creatinine  haemoglobin  \
# 0    normal                 121.0        36.0               1.2         15.4
# 1    normal                 127.0        18.0               0.8         11.3
# 2    normal                 423.0        53.0               1.8          9.6
# 3  abnormal                 117.0        56.0               3.8         11.2
# 4    normal                 106.0        26.0               1.4         11.6
#
#    packed_cell_volume  red_blood_cell_count hypertension diabetes_mellitus  \
# 0                44.0                   5.2          yes               yes
# 1                38.0                   6.1           no                no
# 2                31.0                   3.2           no               yes
# 3                32.0                   3.9          yes                no
# 4                35.0                   4.6           no                no
#
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
chronic_df.iloc[:, 9:17]
# Out:
#      serum_creatinine  haemoglobin  packed_cell_volume  red_blood_cell_count  \
# 0                 1.2         15.4                44.0                   5.2
# 1                 0.8         11.3                38.0                   6.1
# 2                 1.8          9.6                31.0                   3.2
# 3                 3.8         11.2                32.0                   3.9
# 4                 1.4         11.6                35.0                   4.6
# ..                ...          ...                 ...                   ...
# 395               0.5         15.7                47.0                   4.9
# 396               1.2         16.5                54.0                   6.2
# 397               0.6         15.8                49.0                   5.4
# 398               1.0         14.2                51.0                   5.9
# 399               1.1         15.8                53.0                   6.1
#
#     hypertension diabetes_mellitus  class
# 0            yes               yes      0
# 1             no                no      0
# 2             no               yes      0
# 3            yes                no      0
# 4             no                no      0
# ..           ...               ...    ...
# 395           no                no      1
# 396           no                no      1
# 397           no                no      1
# 398           no                no      1
# 399           no                no      1
#
# [400 rows x 7 columns]

# %%
# check unique values in each cat col by looping over cat cols
for col in cat_cols:
    print(f"{col} has {chronic_df[col].unique()} categories\n")
# Out:
# specific_gravity has [1.02  1.01  1.005 1.015 1.025] categories
#
# albumin has [1. 4. 2. 3. 0. 5.] categories
#
# sugar has [0. 3. 4. 1. 2. 5.] categories
#
# red_blood_cells has ['abnormal' 'normal'] categories
#
# pus_cell has ['normal' 'abnormal'] categories
#
# hypertension has ['yes' 'no'] categories
#
# diabetes_mellitus has ['yes' 'no' ' yes' '\tyes'] categories
#
# class has [0 1] categories

# %%
# using labelencoder and applying on cat cols
from sklearn.preprocessing import LabelEncoder

le =  LabelEncoder()

for col in cat_cols[3:]:
    chronic_df[col] =le.fit_transform(chronic_df[col])

# %%
# check chronic df after transforming cat cols
chronic_df.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar  red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0                0
# 1   7.0            50.0             1.020      4.0    0.0                1
# 2  62.0            80.0             1.010      2.0    3.0                1
# 3  48.0            70.0             1.005      4.0    0.0                1
# 4  51.0            80.0             1.010      2.0    0.0                1
#
#    pus_cell  blood_glucose_random  blood_urea  serum_creatinine  haemoglobin  \
# 0         1                 121.0        36.0               1.2         15.4
# 1         1                 127.0        18.0               0.8         11.3
# 2         1                 423.0        53.0               1.8          9.6
# 3         0                 117.0        56.0               3.8         11.2
# 4         1                 106.0        26.0               1.4         11.6
#
#    packed_cell_volume  red_blood_cell_count  hypertension  diabetes_mellitus  \
# 0                44.0                   5.2             1                  3
# 1                38.0                   6.1             0                  2
# 2                31.0                   3.2             0                  3
# 3                32.0                   3.9             1                  2
# 4                35.0                   4.6             0                  2
#
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
chronic_df.iloc[:, 9:17]
# Out:
#      serum_creatinine  haemoglobin  packed_cell_volume  red_blood_cell_count  \
# 0                 1.2         15.4                44.0                   5.2
# 1                 0.8         11.3                38.0                   6.1
# 2                 1.8          9.6                31.0                   3.2
# 3                 3.8         11.2                32.0                   3.9
# 4                 1.4         11.6                35.0                   4.6
# ..                ...          ...                 ...                   ...
# 395               0.5         15.7                47.0                   4.9
# 396               1.2         16.5                54.0                   6.2
# 397               0.6         15.8                49.0                   5.4
# 398               1.0         14.2                51.0                   5.9
# 399               1.1         15.8                53.0                   6.1
#
#      hypertension  diabetes_mellitus  class
# 0               1                  3      0
# 1               0                  2      0
# 2               0                  3      0
# 3               1                  2      0
# 4               0                  2      0
# ..            ...                ...    ...
# 395             0                  2      1
# 396             0                  2      1
# 397             0                  2      1
# 398             0                  2      1
# 399             0                  2      1
#
# [400 rows x 7 columns]

# %%
chronic_df.dtypes
# Out:
# age                     float64
# blood_pressure          float64
# specific_gravity        float64
# albumin                 float64
# sugar                   float64
# red_blood_cells           int32
# pus_cell                  int32
# blood_glucose_random    float64
# blood_urea              float64
# serum_creatinine        float64
# haemoglobin             float64
# packed_cell_volume      float64
# red_blood_cell_count    float64
# hypertension              int32
# diabetes_mellitus         int32
# class                     int64
# dtype: object

# %%
# Split data into features and target variables (X and y)
X = chronic_df.drop('class',axis=1)
y = chronic_df['class']

# %%
# splitting data intp training and test set, so import train_test_split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=0)

# %%
X_train = X_train.values.astype(float)
X_test = X_test.values.astype(float)
y_train = y_train.values
y_test = y_test.values

# %% [markdown]
# ## **`Model Building`**

# %%
# import KNeighborsClassifier, accuracy_score, confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

knn =KNeighborsClassifier()
knn.fit(X_train,y_train)





# accuracy score, confusion matrix and classification report of knn

# Evaluate on test set
knn_acc = accuracy_score(y_test, knn.predict(X_test))

# Print training accuracy
print(f"Training accuracy of KNN is {accuracy_score(y_train, knn.predict(X_train))}")

# Print test accuracy
print(f"Test accuracy of KNN is {knn_acc}\n")

# Print confusion matrix
print(f"Confusion matrix:\n{confusion_matrix(y_test, knn.predict(X_test))}\n")

# Print classification report
print(f"Classification report:\n{classification_report(y_test, knn.predict(X_test))}")
# Out:
# Training accuracy of KNN is 0.8785714285714286
# Test accuracy of KNN is 0.8416666666666667
#
# Confusion matrix:
# [[61 11]
#  [ 8 40]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87        72
#            1       0.78      0.83      0.81        48
#
#     accuracy                           0.84       120
#    macro avg       0.83      0.84      0.84       120
# weighted avg       0.84      0.84      0.84       120

# %%
# import DecisionTreeClassifer
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(X_train,y_train)




# accuracy score, confusion matrix and classification report of decision tree

 
# Evaluate on test set
dtc_acc = accuracy_score(y_test, knn.predict(X_test))

# Print training accuracy
print(f"Training accuracy of dt is {accuracy_score(y_train, dtc.predict(X_train))}")

# Print test accuracy
print(f"Test accuracy of dt is {dtc_acc}\n")

# Print confusion matrix
print(f"Confusion matrix:\n{confusion_matrix(y_test, dtc.predict(X_test))}\n")

# Print classification report
print(f"Classification report:\n{classification_report(y_test, dtc.predict(X_test))}")
# Out:
# Training accuracy of dt is 1.0
# Test accuracy of dt is 0.8416666666666667
#
# Confusion matrix:
# [[72  0]
#  [ 1 47]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        72
#            1       1.00      0.98      0.99        48
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
# hyper parameter tuning of decision tree , import GridSearchCV

from sklearn.model_selection import GridSearchCV


grid_param= {
    'criterion' : ['gini', 'entropy'],
    'max_depth' : [3, 5, 7, 10],
    'splitter' : ['best', 'random'],
    'min_samples_leaf' : [1, 2, 3, 5, 7],
    'min_samples_split' : [2, 3, 5, 7],
    'max_features' : ['auto', 'sqrt', 'log2']
}






# Apply gridsearchcv with cv = 5, n_jobs = -1, verbose = 1
grid_search_dtc = GridSearchCV(dtc,grid_param,cv=5,n_jobs=-1,verbose=1)
grid_search_dtc.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 960 candidates, totalling 4800 fits
# C:\Users\ajeem\anaconda3\envs\surprise310\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3, 5, 7],
#                          'min_samples_split': [2, 3, 5, 7],
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
# print best parameters and best score in grid search dtc
print(grid_search_dtc.best_params_)
print(grid_search_dtc.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.9964285714285716

# %%
# storing best estimator

dtc =grid_search_dtc.best_estimator_

# accuracy score, confusion matrix and classification report of decision tree

 
# Evaluate on test set
dtc_acc = accuracy_score(y_test, knn.predict(X_test))

# Print training accuracy
print(f"Training accuracy of KNN is {accuracy_score(y_train, dtc.predict(X_train))}")

# Print test accuracy
print(f"Test accuracy of KNN is {dtc_acc}\n")

# Print confusion matrix
print(f"Confusion matrix:\n{confusion_matrix(y_test, dtc.predict(X_test))}\n")

# Print classification report
print(f"Classification report:\n{classification_report(y_test, dtc.predict(X_test))}")
# Out:
# Training accuracy of KNN is 0.9928571428571429
# Test accuracy of KNN is 0.8416666666666667
#
# Confusion matrix:
# [[70  2]
#  [ 4 44]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        72
#            1       0.96      0.92      0.94        48
#
#     accuracy                           0.95       120
#    macro avg       0.95      0.94      0.95       120
# weighted avg       0.95      0.95      0.95       120

# %%
# import RandomForestClassifier

from sklearn.ensemble import RandomForestClassifier

rd_clf =RandomForestClassifier() 
rd_clf.fit(X_train,y_train)



# accuracy score, confusion matrix and classification report of random forest

rd_clf_acc =accuracy_score(y_test, rd_clf.predict(X_test)) 

# Print training accuracy
print(f"Training accuracy of rd is {accuracy_score(y_train, rd_clf.predict(X_train))}")

# Print test accuracy
print(f"Test accuracy of rd is {rd_clf_acc}\n")

# Print confusion matrix
print(f"Confusion matrix:\n{confusion_matrix(y_test, rd_clf.predict(X_test))}\n")

# Print classification report
print(f"Classification report:\n{classification_report(y_test, rd_clf.predict(X_test))}")
# Out:
# Training accuracy of rd is 1.0
# Test accuracy of rd is 0.9916666666666667
#
# Confusion matrix:
# [[72  0]
#  [ 1 47]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        72
#            1       1.00      0.98      0.99        48
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
# import AdaBoostClassifier
from sklearn.ensemble import AdaBoostClassifier

ada =AdaBoostClassifier()
ada.fit(X_train,y_train)



# accuracy score, confusion matrix and classification report of ada boost

ada_acc = accuracy_score(y_test, ada.predict(X_test)) 

# Print training accuracy
print(f"Training accuracy of ada is {accuracy_score(y_train, ada.predict(X_train))}")

# Print test accuracy
print(f"Test accuracy of ada is {ada_acc}\n")

# Print confusion matrix
print(f"Confusion matrix:\n{confusion_matrix(y_test, ada.predict(X_test))}\n")

# Print classification report
print(f"Classification report:\n{classification_report(y_test,ada.predict(X_test))}")
# Out:
# Training accuracy of ada is 1.0
# Test accuracy of ada is 1.0
#
# Confusion matrix:
# [[72  0]
#  [ 0 48]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        72
#            1       1.00      1.00      1.00        48
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120

# %%
# import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()
gb.fit(X_train,y_train)



# accuracy score, confusion matrix and classification report of gradient boosting classifier

gb_acc = accuracy_score(y_test, gb.predict(X_test)) 

# Print training accuracy
print(f"Training accuracy of gb is {accuracy_score(y_train, gb.predict(X_train))}")

# Print test accuracy
print(f"Test accuracy of gb is {gb_acc}\n")

# Print confusion matrix
print(f"Confusion matrix:\n{confusion_matrix(y_test, gb.predict(X_test))}\n")

# Print classification report
print(f"Classification report:\n{classification_report(y_test, gb.predict(X_test))}")
# Out:
# Training accuracy of gb is 1.0
# Test accuracy of gb is 0.9916666666666667
#
# Confusion matrix:
# [[71  1]
#  [ 0 48]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        72
#            1       0.98      1.00      0.99        48
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
# using max_depth = 4, subsample = 0.90, max_features = 0.75, n_estimators = 200
sgb = GradientBoostingClassifier(max_depth=4,subsample=0.90,max_features=0.75,n_estimators=200)
sgb.fit(X_train,y_train)



# accuracy score, confusion matrix and classification report of stochastic gradient boosting classifier

sgb_acc = accuracy_score(y_test, sgb.predict(X_test)) 

# Print training accuracy
print(f"Training accuracy of sgb is {accuracy_score(y_train, sgb.predict(X_train))}")

# Print test accuracy
print(f"Test accuracy of sgb is {sgb_acc}\n")

# Print confusion matrix
print(f"Confusion matrix:\n{confusion_matrix(y_test, sgb.predict(X_test))}\n")

# Print classification report
print(f"Classification report:\n{classification_report(y_test, sgb.predict(X_test))}")
# Out:
# Training accuracy of sgb is 1.0
# Test accuracy of sgb is 0.9833333333333333
#
# Confusion matrix:
# [[71  1]
#  [ 1 47]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        72
#            1       0.98      0.98      0.98        48
#
#     accuracy                           0.98       120
#    macro avg       0.98      0.98      0.98       120
# weighted avg       0.98      0.98      0.98       120

# %%
# import XGBClassifier
from xgboost import XGBClassifier

xgb = XGBClassifier()
xgb.fit(X_train,y_train)



# accuracy score, confusion matrix and classification report of xgboost

xgb_acc =accuracy_score(y_test, xgb.predict(X_test)) 

# Print training accuracy
print(f"Training accuracy of xgb is {accuracy_score(y_train, xgb.predict(X_train))}")

# Print test accuracy
print(f"Test accuracy of xgb is {xgb_acc}\n")

# Print confusion matrix
print(f"Confusion matrix:\n{confusion_matrix(y_test, xgb.predict(X_test))}\n")

# Print classification report
print(f"Classification report:\n{classification_report(y_test, xgb.predict(X_test))}")
# Out:
# Training accuracy of xgb is 1.0
# Test accuracy of xgb is 0.9833333333333333
#
# Confusion matrix:
# [[72  0]
#  [ 2 46]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        72
#            1       1.00      0.96      0.98        48
#
#     accuracy                           0.98       120
#    macro avg       0.99      0.98      0.98       120
# weighted avg       0.98      0.98      0.98       120

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Using cached catboost-1.2.10-cp310-cp310-win_amd64.whl.metadata (1.5 kB)
# Collecting graphviz (from catboost)
#   Using cached graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from catboost) (3.10.8)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas<4.0,>=0.24 in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from catboost) (2.3.3)
# Requirement already satisfied: scipy in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from catboost) (1.15.3)
# Collecting plotly (from catboost)
#   Using cached plotly-6.5.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: six in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from pandas<4.0,>=0.24->catboost) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from matplotlib->catboost) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\ajeem\anaconda3\envs\surprise310\lib\site-packages (from matplotlib->catboost) (3.2.5)
# Collecting narwhals>=1.15.1 (from plotly->catboost)
#   Downloading narwhals-2.17.0-py3-none-any.whl.metadata (14 kB)
# Using cached catboost-1.2.10-cp310-cp310-win_amd64.whl (100.2 MB)
# Using cached graphviz-0.21-py3-none-any.whl (47 kB)
# Using cached plotly-6.5.2-py3-none-any.whl (9.9 MB)
# Downloading narwhals-2.17.0-py3-none-any.whl (444 kB)
# Installing collected packages: narwhals, graphviz, plotly, catboost
#
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------- ----------------------------- 1/4 [graphviz]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    -------------------- ------------------- 2/4 [plotly]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ------------------------------ --------- 3/4 [catboost]
#    ---------------------------------------- 4/4 [catboost]
#
# Successfully installed catboost-1.2.10 graphviz-0.21 narwhals-2.17.0 plotly-6.5.2

# %%
# import CatBoostClassifier
from catboost import CatBoostClassifier

cat = CatBoostClassifier()
cat.fit(X_train,y_train)


# accuracy score, confusion matrix and classification report of cat boost

cat_acc = accuracy_score(y_test, cat.predict(X_test)) 

# Print training accuracy
print(f"Training accuracy of cat is {accuracy_score(y_train, cat.predict(X_train))}")

# Print test accuracy
print(f"Test accuracy of cat is {cat_acc}\n")

# Print confusion matrix
print(f"Confusion matrix:\n{confusion_matrix(y_test, cat.predict(X_test))}\n")

# Print classification report
print(f"Classification report:\n{classification_report(y_test, cat.predict(X_test))}")
# Out:
# Learning rate set to 0.005982
# 0:	learn: 0.6841305	total: 142ms	remaining: 2m 21s
# 1:	learn: 0.6759517	total: 144ms	remaining: 1m 11s
# 2:	learn: 0.6684587	total: 145ms	remaining: 48.3s
# 3:	learn: 0.6595118	total: 147ms	remaining: 36.5s
#
#            0       1.00      0.99      0.99        72
#            1       0.98      1.00      0.99        48
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
# import ExtraTreesClassifier

from sklearn.ensemble import ExtraTreesClassifier

etc = ExtraTreesClassifier()
etc.fit(X_train,y_train)




# accuracy score, confusion matrix and classification report of extra trees classifier

etc_acc = accuracy_score(y_test, etc.predict(X_test)) 

# Print training accuracy
print(f"Training accuracy of etc is {accuracy_score(y_train, etc.predict(X_train))}")

# Print test accuracy
print(f"Test accuracy of etc is {etc_acc}\n")

# Print confusion matrix
print(f"Confusion matrix:\n{confusion_matrix(y_test, etc.predict(X_test))}\n")

# Print classification report
print(f"Classification report:\n{classification_report(y_test, etc.predict(X_test))}")
# Out:
# Training accuracy of etc is 1.0
# Test accuracy of etc is 1.0
#
# Confusion matrix:
# [[72  0]
#  [ 0 48]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        72
#            1       1.00      1.00      1.00        48
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120

# %%
# import LGBMClassifier
from lightgbm import LGBMClassifier

lgbm = LGBMClassifier()
lgbm.fit(X_train,y_train)




# accuracy score, confusion matrix and classification report of lgbm classifier

lgbm_acc =accuracy_score(y_test, lgbm.predict(X_test)) 

# Print training accuracy
print(f"Training accuracy of lgbm is {accuracy_score(y_train, lgbm.predict(X_train))}")

# Print test accuracy
print(f"Test accuracy of lgbm is {lgbm_acc}\n")

# Print confusion matrix
print(f"Confusion matrix:\n{confusion_matrix(y_test, lgbm.predict(X_test))}\n")

# Print classification report
print(f"Classification report:\n{classification_report(y_test, lgbm.predict(X_test))}")
# Out:
# [LightGBM] [Info] Number of positive: 102, number of negative: 178
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000226 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 396
# [LightGBM] [Info] Number of data points in the train set: 280, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.364286 -> initscore=-0.556811
# [LightGBM] [Info] Start training from score -0.556811
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training accuracy of lgbm is 1.0
# Test accuracy of lgbm is 0.9916666666666667
#
# Confusion matrix:
# [[72  0]
#  [ 1 47]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        72
#            1       1.00      0.98      0.99        48
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
# comparing all models accuracy by creating a df
models = pd.DataFrame({
     'Model': ['KNN','Decision Tree Classifier','Random Forest Classifier','Ada Boost Classifier',
         'Gradient Boosting Classifier','Stochastic Gradient Boosting','XgBoost','Cat Boost','Extra Trees Classifier'],
      'Score':[knn_acc,dtc_acc,rd_clf_acc,ada_acc,gb_acc,sgb_acc,xgb_acc,cat_acc,etc_acc]

})


 
#sort values by score 
models.sort_values(by='Score',ascending=False)
# Out:
#                           Model     Score
# 3          Ada Boost Classifier  1.000000
# 8        Extra Trees Classifier  1.000000
# 2      Random Forest Classifier  0.991667
# 4  Gradient Boosting Classifier  0.991667
# 7                     Cat Boost  0.991667
# 5  Stochastic Gradient Boosting  0.983333
# 6                       XgBoost  0.983333
# 0                           KNN  0.841667
# 1      Decision Tree Classifier  0.841667

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(ada, X, y, cv=5)
print("CV Mean:", scores.mean())
print("CV Std:", scores.std())
# Out:
# CV Mean: 0.9800000000000001
# CV Std: 0.016955824957813195

# %%
from sklearn.metrics import roc_auc_score

y_prob = ada.predict_proba(X_test)[:,1]
print("AUC:", roc_auc_score(y_test, y_prob))
# Out:
# AUC: 1.0

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV

# Model
ada = AdaBoostClassifier(random_state=42)

# Hyperparameter grid
param_grid = {
    'n_estimators': [30, 50, 70, 100, 150],
    'learning_rate': [0.01, 0.1, 0.5, 1.0]
}

# GridSearch
grid = GridSearchCV(
    estimator=ada,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X, y)

print("Best Parameters:", grid.best_params_)
print("Best CV Score:", grid.best_score_)
# Out:
# Best Parameters: {'learning_rate': 0.01, 'n_estimators': 100}
# Best CV Score: 0.9875

# %%
final_ada = AdaBoostClassifier(
    learning_rate=0.1,
    n_estimators=70,
    random_state=42
)

final_ada.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.1, n_estimators=70, random_state=42)

# %%
from sklearn.metrics import accuracy_score

# Training accuracy
train_pred = final_ada.predict(X_train)
print("Training Accuracy:", accuracy_score(y_train, train_pred))

# Test accuracy
test_pred = final_ada.predict(X_test)
print("Test Accuracy:", accuracy_score(y_test, test_pred))
# Out:
# Training Accuracy: 1.0
# Test Accuracy: 0.9916666666666667

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, test_pred))
# Out:
# [[71  1]
#  [ 0 48]]

# %%
from sklearn.metrics import roc_auc_score

y_prob = final_ada.predict_proba(X_test)[:,1]
print("AUC:", roc_auc_score(y_test, y_prob))
# Out:
# AUC: 0.9997106481481481

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score

rskf = RepeatedStratifiedKFold(
    n_splits=5,
    n_repeats=10,
    random_state=42
)

scores = cross_val_score(
    final_ada,
    X,
    y,
    scoring='accuracy',
    cv=rskf,
    n_jobs=-1
)

print("Robust CV Mean:", scores.mean())
print("Robust CV Std:", scores.std())
# Out:
# Robust CV Mean: 0.983
# Robust CV Std: 0.014089002803605385

# %%
recall_scores = cross_val_score(
    final_ada,
    X,
    y,
    scoring='recall',
    cv=rskf,
    n_jobs=-1
)

print("Recall Mean:", recall_scores.mean())
# Out:
# Recall Mean: 0.9806666666666666

# %%
import joblib
import json

# सिर्फ ये दो फाइल्स सेव करें - LabelEncoder नहीं
joblib.dump(final_ada, 'adaboost_kidney_model.pkl')  # सिर्फ मॉडल

with open('features_columns.json', 'w') as f:
    json.dump(list(X.columns), f)  # फीचर नाम
